# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### Download and unzip Yale data

# %%
# !wget -O "/content/drive/MyDrive/Colab Notebooks/Enhance Fisher face/data/yalefaces.zip" http://vision.ucsd.edu/datasets/yale_face_dataset_original/yalefaces.zip
# Out:
# --2022-02-08 17:56:32--  http://vision.ucsd.edu/datasets/yale_face_dataset_original/yalefaces.zip
# Resolving vision.ucsd.edu (vision.ucsd.edu)... 132.239.95.98
# Connecting to vision.ucsd.edu (vision.ucsd.edu)|132.239.95.98|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6206308 (5.9M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Colab Notebooks/yalefaces.zip’
#
# /content/drive/MyDr 100%[===================>]   5.92M   655KB/s    in 9.4s
#
# 2022-02-08 17:56:41 (646 KB/s) - ‘/content/drive/MyDrive/Colab Notebooks/yalefaces.zip’ saved [6206308/6206308]

# %%
# !unzip "/content/drive/MyDrive/Colab Notebooks/Enhance Fisher face/data/yalefaces.zip" -d "/content/drive/MyDrive/Colab Notebooks/Enhance Fisher face/data/"
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/Enhance Fisher face/data/yalefaces.zip
#    creating: /content/drive/MyDrive/Colab Notebooks/yalefaces/
#   inflating: /content/drive/MyDrive/Colab Notebooks/yalefaces/Readme.txt
#    creating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/
#    creating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/yalefaces/
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/yalefaces/._Readme.txt
#   inflating: /content/drive/MyDrive/Colab Notebooks/yalefaces/subject01.gif
#   inflating: /content/drive/MyDrive/Colab Notebooks/yalefaces/subject01.glasses
#   inflating: /content/drive/MyDrive/Colab Notebooks/yalefaces/subject01.glasses.gif
#   inflating: /content/drive/MyDrive/Colab Notebooks/yalefaces/subject01.happy
#   inflating: /content/drive/MyDrive/Colab Notebooks/yalefaces/subject01.leftlight
#   inflating: /content/drive/MyDrive/Colab Notebooks/yalefaces/subject01.noglasses
# ...
