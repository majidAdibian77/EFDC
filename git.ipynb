# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/Enhance Fisher face/'
# Out:
# /content/drive/MyDrive/Colab Notebooks/Enhance Fisher face

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/Enhance Fisher face/.git/

# %%
# !git config --global core.excludesfile '/content/drive/MyDrive/Colab Notebooks/Enhance Fisher face/.gitignore_global'

# %%
# !git config --global user.email "majidad09@gmail.com"
# !git config --global user.name "Majid"

# %%
# !git remote add origin https://majidAdibian77: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@github.com/majidAdibian77/EFDC.git

# %%
# !git add --all

# %%
# !git commit -m "Finish implementation"
# Out:
# [master 7d24324] Finish implementation
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 .gitignore.txt

# %%
1!git push -u origin master
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (4/4), 2.28 KiB | 582.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/majidAdibian77/EFDC.git
#    695be81..7d24324  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
# !git rm --cached filename
# Out:
# fatal: pathspec 'filename' did not match any files
